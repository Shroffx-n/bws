# %%
from PIL import Image, ImageDraw, ImageFont

def create_icon(size, filename):
    img = Image.new('RGB', (size, size), color='#0060df')
    draw = ImageDraw.Draw(img)
    
    # Draw "PT" text
    try:
        font = ImageFont.truetype("arial.ttf", size // 2)
    except:
        font = ImageFont.load_default()
    
    text = "PT"
    bbox = draw.textbbox((0, 0), text, font=font)
    text_width = bbox[2] - bbox[0]
    text_height = bbox[3] - bbox[1]
    
    position = ((size - text_width) // 2, (size - text_height) // 2 - size // 10)
    draw.text(position, text, fill='white', font=font)
    
    img.save(filename)

create_icon(48, 'icons/icon-48.png')
create_icon(96, 'icons/icon-96.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 23
#      19     draw.text(position, text, fill='white', font=font)
#      21     img.save(filename)
# ---> 23 create_icon(48, 'icons/icon-48.png')
#      24 create_icon(96, 'icons/icon-96.png')
#
# Cell In[5], line 21, in create_icon(size, filename)
#      18 position = ((size - text_width) // 2, (size - text_height) // 2 - size // 10)
#      19 draw.text(position, text, fill='white', font=font)
# ---> 21 img.save(filename)
#
# File ~/.local/lib/python3.10/site-packages/PIL/Image.py:2585, in Image.save(self, fp, format, **params)
#    2583         fp = builtins.open(filename, "r+b")
#    2584     else:
# -> 2585         fp = builtins.open(filename, "w+b")
#    2586 else:
#    2587     fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'icons/icon-48.png'

# %%
# !pip install pillow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pillow
#   Downloading pillow-12.1.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Downloading pillow-12.1.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 1.3 MB/s eta 0:00:001.3 MB/s eta 0:00:010m
# Installing collected packages: pillow
# Successfully installed pillow-12.1.0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
